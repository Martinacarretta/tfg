# %% [markdown]
# # Notebook to experiment with training:

# %% [markdown]
# https://docs.pytorch.org/tutorials/intermediate/reinforcement_q_learning.html

# %% [markdown]
# ## Code:

# %%
import wandb
import numpy as np
from gymnasium import spaces
import random
import torch

# %%
SEED = 42
# Python RNG
random.seed(SEED)

# NumPy RNG
np.random.seed(SEED)

# PyTorch RNG (CPU + GPU)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
import itertools
import json
import os

# === Configuration ===
START_TRIAL = 19  # start numbering from Trial019
PROGRESS_FILE = "grid_progress.json"

RUN_NAME_BASE = "Trial"
ENVIRONMENT = "Glioblastoma"
NET = "DQN"
AGENT = "DQNAgent"
BUFFER = "ReplayBuffer"
NOTES = ""

LR = 1e-4
MEMORY_SIZE = 15000
MAX_EPISODES = 90
GAMMA = 0.99
DECAY_TYPE = "exponential"
BATCH_SIZE = 128
DNN_UPD = 1
DNN_SYNC = 20

# --- Grid parameters ---
reward_grid = [
    [10.0, -2.0, -0.5],
    [5.0, -1.0, -0.2],
    [8.0, -1.5, -0.3],
]

burnin_grid = [100, 150, 200, 500]
epsilon_grid = [1.0, 0.9, 0.7]
epsilon_min_grid = [0.1, 0.05]
epsilon_decay_grid = [0.95, 0.9, 0.85, 0.8]


if os.path.exists(PROGRESS_FILE):
    with open(PROGRESS_FILE, "r") as f:
        progress = json.load(f)
    completed = set(progress.get("completed", []))
    current_trial = progress.get("last_trial", START_TRIAL)
else:
    completed = set()
    current_trial = START_TRIAL

print(f"Resuming from trial {current_trial:03d}, {len(completed)} of {total} completed.")


# --- Training function ---
def train_grid(instance_gid, rewards, burnin, eps, eps_min, eps_decay):
    CURRENT_CONFIG = {
        'grid_size': 4,
        'rewards': rewards,
        'action_space': spaces.Discrete(3)
    }

    from training_environments import prepare, Glioblastoma
    from training_dqn import DQN
    from training_agents import DQNAgent
    from training_buffers import ReplayBuffer
    
    train_pairs = prepare()
    env = Glioblastoma(*train_pairs[0], **CURRENT_CONFIG)
    print(env.observation_space.shape)
    print(env.action_space.n)
    print(np.arange(env.action_space.n))

    net = DQN(env, learning_rate=LR, device='cpu')
    buffer = ReplayBuffer(capacity=MEMORY_SIZE)
    agent = DQNAgent(env_config=CURRENT_CONFIG, dnnetwork=net, buffer_class=ReplayBuffer,
                    train_pairs=train_pairs, env_class=Glioblastoma,
                    epsilon=eps, eps_decay=eps_decay, eps_decay_type=DECAY_TYPE, epsilon_min=eps_min,
                    batch_size=BATCH_SIZE, gamma=GAMMA,
                    memory_size=MEMORY_SIZE, buffer_initial=burnin,
                    save_name=instance_gid)

    wandb.login()
    wandb.init(
        project="TFG_Glioblastoma",
        name=instance_gid,
        id=instance_gid,
        config={
            "environment": ENVIRONMENT,
            "configuration": CURRENT_CONFIG,
            "model": NET,
            "agent": AGENT,
            "buffer": BUFFER,
            "notes": NOTES,
            "lr": LR,
            "MEMORY_SIZE": MEMORY_SIZE,
            "MAX_EPISODES": MAX_EPISODES,
            "EPSILON": eps,
            "EPSILON_DECAY": eps_decay,
            "Decay type": DECAY_TYPE,
            "EPSILON_MIN": eps_min,
            "GAMMA": GAMMA,
            "BATCH_SIZE": BATCH_SIZE,
            "BURN_IN": burnin,
            "DNN_UPD": DNN_UPD,
            "DNN_SYNC": DNN_SYNC,
            "rewards": rewards,
        }
    )

    agent.train(
        train_pairs=train_pairs,
        gamma=GAMMA,
        max_episodes=MAX_EPISODES,
        dnn_update_frequency=DNN_UPD,
        dnn_sync_frequency=DNN_SYNC
    )
    wandb.finish()


# --- Grid Search Loop ---
all_combos = list(itertools.product(
    reward_grid,
    burnin_grid,
    epsilon_grid,
    epsilon_min_grid,
    epsilon_decay_grid
))

total = len(all_combos)
print(f"Total combinations: {total}")


for i, combo in enumerate(all_combos):
    combo_id = str(i)
    if combo_id in completed:
        continue  # skip already finished runs

    rewards, burnin, eps, eps_min, eps_decay = combo
    run_id = f"{RUN_NAME_BASE}{current_trial:03d}"

    print(f"\n=== Running {run_id} ({i+1}/{total}) ===")

    try:
        train_grid(run_id, rewards, burnin, eps, eps_min, eps_decay)
        # --- Save progress after each successful run ---
        completed.add(combo_id)
        current_trial += 1
        with open(PROGRESS_FILE, "w") as f:
            json.dump({"completed": list(completed), "last_trial": current_trial}, f)
    except Exception as e:
        print(f"❌ Error on {run_id}: {e}")
        break

print("\n✅ Grid search finished or interrupted. Progress saved.")
# Out:
# Total combinations: 288
#
# === Running GridSearch_R000_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R001_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R002_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R003_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R004_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R005_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R006_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R007_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R008_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R009_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R010_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R011_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R012_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R013_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R014_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R015_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R016_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R017_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R018_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R019_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R020_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R021_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R022_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R023_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R024_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R025_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R026_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R027_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R028_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R029_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R030_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R031_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R032_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R033_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R034_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R035_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R036_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R037_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R038_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R039_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R040_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R041_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R042_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R043_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R044_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R045_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R046_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R047_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R048_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R049_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R050_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R051_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R052_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R053_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R054_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R055_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R056_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R057_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R058_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R059_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R060_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R061_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R062_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R063_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R064_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R065_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R066_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R067_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R068_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R069_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R070_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R071_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R072_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R073_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R074_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R075_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R076_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R077_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R078_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R079_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R080_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R081_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R082_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R083_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R084_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R085_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R086_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R087_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R088_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R089_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R090_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R091_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R092_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R093_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R094_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R095_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R096_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R097_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R098_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R099_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R100_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R101_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R102_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R103_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R104_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R105_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R106_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R107_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R108_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R109_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R110_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R111_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R112_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R113_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R114_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R115_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R116_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R117_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R118_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R119_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R120_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R121_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R122_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R123_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R124_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R125_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R126_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R127_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R128_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R129_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R130_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R131_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R132_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R133_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R134_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R135_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R136_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R137_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R138_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R139_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R140_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R141_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R142_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R143_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R144_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R145_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R146_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R147_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R148_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R149_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R150_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R151_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R152_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R153_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R154_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R155_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R156_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R157_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R158_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R159_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R160_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R161_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R162_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R163_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R164_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R165_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R166_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R167_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R168_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R169_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R170_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R171_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R172_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R173_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R174_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R175_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R176_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R177_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R178_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R179_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R180_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R181_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R182_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R183_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R184_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R185_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R186_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R187_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R188_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R189_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R190_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R191_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R192_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R193_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R194_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R195_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R196_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R197_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R198_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R199_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R200_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R201_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R202_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R203_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R204_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R205_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R206_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R207_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R208_decay0.95_burn100_epsmin0.1 ===
#
# === Running GridSearch_R209_decay0.9_burn100_epsmin0.1 ===
#
# === Running GridSearch_R210_decay0.85_burn100_epsmin0.1 ===
#
# === Running GridSearch_R211_decay0.8_burn100_epsmin0.1 ===
#
# === Running GridSearch_R212_decay0.95_burn100_epsmin0.05 ===
#
# === Running GridSearch_R213_decay0.9_burn100_epsmin0.05 ===
#
# === Running GridSearch_R214_decay0.85_burn100_epsmin0.05 ===
#
# === Running GridSearch_R215_decay0.8_burn100_epsmin0.05 ===
#
# === Running GridSearch_R216_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R217_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R218_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R219_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R220_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R221_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R222_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R223_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R224_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R225_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R226_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R227_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R228_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R229_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R230_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R231_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R232_decay0.95_burn150_epsmin0.1 ===
#
# === Running GridSearch_R233_decay0.9_burn150_epsmin0.1 ===
#
# === Running GridSearch_R234_decay0.85_burn150_epsmin0.1 ===
#
# === Running GridSearch_R235_decay0.8_burn150_epsmin0.1 ===
#
# === Running GridSearch_R236_decay0.95_burn150_epsmin0.05 ===
#
# === Running GridSearch_R237_decay0.9_burn150_epsmin0.05 ===
#
# === Running GridSearch_R238_decay0.85_burn150_epsmin0.05 ===
#
# === Running GridSearch_R239_decay0.8_burn150_epsmin0.05 ===
#
# === Running GridSearch_R240_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R241_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R242_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R243_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R244_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R245_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R246_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R247_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R248_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R249_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R250_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R251_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R252_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R253_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R254_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R255_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R256_decay0.95_burn200_epsmin0.1 ===
#
# === Running GridSearch_R257_decay0.9_burn200_epsmin0.1 ===
#
# === Running GridSearch_R258_decay0.85_burn200_epsmin0.1 ===
#
# === Running GridSearch_R259_decay0.8_burn200_epsmin0.1 ===
#
# === Running GridSearch_R260_decay0.95_burn200_epsmin0.05 ===
#
# === Running GridSearch_R261_decay0.9_burn200_epsmin0.05 ===
#
# === Running GridSearch_R262_decay0.85_burn200_epsmin0.05 ===
#
# === Running GridSearch_R263_decay0.8_burn200_epsmin0.05 ===
#
# === Running GridSearch_R264_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R265_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R266_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R267_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R268_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R269_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R270_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R271_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R272_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R273_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R274_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R275_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R276_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R277_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R278_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R279_decay0.8_burn500_epsmin0.05 ===
#
# === Running GridSearch_R280_decay0.95_burn500_epsmin0.1 ===
#
# === Running GridSearch_R281_decay0.9_burn500_epsmin0.1 ===
#
# === Running GridSearch_R282_decay0.85_burn500_epsmin0.1 ===
#
# === Running GridSearch_R283_decay0.8_burn500_epsmin0.1 ===
#
# === Running GridSearch_R284_decay0.95_burn500_epsmin0.05 ===
#
# === Running GridSearch_R285_decay0.9_burn500_epsmin0.05 ===
#
# === Running GridSearch_R286_decay0.85_burn500_epsmin0.05 ===
#
# === Running GridSearch_R287_decay0.8_burn500_epsmin0.05 ===
