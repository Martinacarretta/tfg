# %% [markdown]
# # Notebook to experiment with testing:

# %% [markdown]
# ## Code:

# %%
import numpy as np
import random
import torch
from gymnasium import spaces
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from gymnasium import spaces

SEED = 42
# Python RNG
random.seed(SEED)

# NumPy RNG
np.random.seed(SEED)

# PyTorch RNG (CPU + GPU)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed(SEED)
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
import sys
sys.path.append("/home/martina/codi2/4year/tfg")  # add parent folder of general.py

from general import prepare, Glioblastoma, Glioblastoma2, testing

# %%
test_pairs = prepare(mode='test')
# Out:
# ✅ Found 100 pairs out of 100 listed in CSV.

# %%
class CNNPolicy(nn.Module):
    def __init__(self, action_dim, channels=1):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(channels, 16, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=5, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2),
            nn.ReLU(),
        )

        self.fc = nn.Sequential(
            nn.Linear(64 * 5 * 5, 256),   # flatten size for 60x60 input
            nn.ReLU(),
            nn.Linear(256, action_dim),
            nn.Softmax(dim=-1)
        )

    def forward(self, x):
        x = self.cnn(x)
        x = x.flatten(1)
        return self.fc(x), None

    def act(self, state):
        # state shape: (60,60) or (1,60,60)
        state = torch.tensor(state, dtype=torch.float32)

        if state.ndim == 2:
            state = state.unsqueeze(0)  # (1,60,60)
        if state.ndim == 3:
            state = state.unsqueeze(0)  # (1,1,60,60)

        probs, _ = self.forward(state)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()

        return action.item(), dist.log_prob(action)

class REINFORCEAgent:
    def __init__(self, env_class, train_pairs, env_config,
                 gamma=0.99, lr=1e-4):

        self.env_class = env_class
        self.train_pairs = train_pairs
        self.env_config = env_config
        self.gamma = gamma

        # Create sample env to read obs shape
        sample_img, sample_mask = train_pairs[0]

        sample_env = env_class(
            sample_img,
            sample_mask,
            grid_size=env_config["grid_size"],
            rewards=env_config["rewards"],
            action_space=env_config["action_space"]
        )

        obs, _ = sample_env.reset()

        channels = 1 if obs.ndim == 2 else obs.shape[0]

        self.action_dim = env_config["action_space"].n
        self.policy = CNNPolicy(self.action_dim, channels)
        self.model = self.policy
        self.optim = optim.Adam(self.policy.parameters(), lr=lr)
        self.best_reward = -1e9
        self.save_path = "reinforce_policy.pt"


    def run_episode(self, img_path, mask_path):
        env = self.env_class(
            img_path,
            mask_path,
            grid_size=self.env_config["grid_size"],
            rewards=self.env_config["rewards"],
            action_space=self.env_config["action_space"]
        )

        log_probs = []
        rewards = []

        state, _ = env.reset()
        done = False

        while not done:
            action, log_prob = self.policy.act(state)
            next_state, reward, terminated, truncated, _ = env.step(action)

            log_probs.append(log_prob)
            rewards.append(reward)

            state = next_state
            done = terminated or truncated

        return log_probs, rewards


    def compute_returns(self, rewards):
        G = 0
        returns = []
        for r in reversed(rewards):
            G = r + self.gamma * G
            returns.insert(0, G)
        returns = torch.tensor(returns, dtype=torch.float32)
        return (returns - returns.mean()) / (returns.std() + 1e-8)

    def update_policy(self, log_probs, returns):
        loss = []
        for lp, Gt in zip(log_probs, returns):
            loss.append(-lp * Gt)

        loss = torch.stack(loss).sum()

        self.optim.zero_grad()
        loss.backward()
        self.optim.step()
        return loss.item()


    # Train over ALL train_pairs each epoch
    def train(self, epochs=200):
        for e in range(epochs):
            epoch_loss = 0
            epoch_reward = 0

            epoch_rewards = []
            # Train on ALL image/mask pairs each epoch
            for i, (img_path, mask_path) in enumerate(self.train_pairs):
                log_probs, rewards = self.run_episode(img_path, mask_path)
                returns = self.compute_returns(rewards)
                loss = self.update_policy(log_probs, returns)

                epoch_loss += loss
                epoch_rewards.append(sum(rewards))
                if i % 10 == 0:
                    print(f"  episode = {i} | Episode Reward={sum(rewards):.2f} | Loss={loss:.4f}")
            
            avg_reward = np.mean(epoch_rewards)
            # Save best model so far
            if avg_reward > self.best_reward:
                self.best_reward = avg_reward
                torch.save(self.policy.state_dict(), self.save_path)
                print(f"  -> Saved new best model (Reward {avg_reward:.2f})")

            if e % 10 == 0:
                print(f"[Epoch {e+1}] Avg Reward per Episode={avg_reward:.2f} | Loss={epoch_loss:.4f}")

        torch.save(self.policy.state_dict(), "reinforce_final.pt")
        print("Training finished. Final model saved to reinforce_final.pt")

# %% [markdown]
# # TESTING:

# %%
# load model to test:
LR = 1e-4 #From paper
CURRENT_CONFIG = {
    'grid_size': 4,
    'rewards': [5.0, -1.0, -0.2], 
    'action_space': spaces.Discrete(3)
}


agent = REINFORCEAgent(
    env_class=Glioblastoma,
    train_pairs=test_pairs,
    env_config=CURRENT_CONFIG,
    gamma=0.99,
    lr=1e-4
)

agent.policy.load_state_dict(torch.load("reinforce_final.pt"))
# Out:
# <All keys matched successfully>

# %%
overall_results = testing(agent, test_pairs, agent_type="reinforce", num_episodes=len(test_pairs), env_config=CURRENT_CONFIG, save_gifs=True, gif_folder="TEST_GIFS")
# Out:
# Saved GIF for episode 0 at TEST_GIFS/episode_0_002_58.gif
# Saved GIF for episode 10 at TEST_GIFS/episode_10_013_86.gif
# Saved GIF for episode 20 at TEST_GIFS/episode_20_024_49.gif
# Saved GIF for episode 30 at TEST_GIFS/episode_30_038_84.gif
# Saved GIF for episode 40 at TEST_GIFS/episode_40_052_98.gif
# Saved GIF for episode 50 at TEST_GIFS/episode_50_104_74.gif
# Saved GIF for episode 60 at TEST_GIFS/episode_60_176_99.gif
# Saved GIF for episode 70 at TEST_GIFS/episode_70_204_52.gif
# Saved GIF for episode 80 at TEST_GIFS/episode_80_260_62.gif
# Saved GIF for episode 90 at TEST_GIFS/episode_90_300_107.gif
#
# ============================================================
# TEST RESULTS (REINFORCE Agent)
# ============================================================
# Success Rate: 49.00%
# Average Episode Reward: 23.78
# Average Steps to Find Tumor: 10.85
# Average Tumor Rewards per Episode: 6.98
# Tumor Size Statistics:
#   Biggest Tumor: 4910 pixels (8.52%)
#   Smallest Tumor: 296 pixels (0.51%)
#   Average Tumor: 1873 pixels (3.25%)
# Overall Action Distribution: [0.788 0.111 0.101]
#   Successful Episodes: [0.87755102 0.06632653 0.05612245]
#   Unsuccessful Episodes: [0.70196078 0.15392157 0.14411765]
#
# Detailed Results for 100 episodes:
# --------------------------------------------------------------------------------
# Episode 0: 002_58.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2049 pixels (3.56%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_0_002_58.gif
#
# Episode 1: 004_87.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 2727 pixels (4.73%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_1_004_87.gif
#
# Episode 2: 005_94.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 768 pixels (1.33%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_2_005_94.gif
#
# Episode 3: 006_83.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 2834 pixels (4.92%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_3_006_83.gif
#
# Episode 4: 007_54.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1299 pixels (2.26%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_4_007_54.gif
#
# Episode 5: 008_41.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 1243 pixels (2.16%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_5_008_41.gif
#
# Episode 6: 009_65.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 4172 pixels (7.24%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_6_009_65.gif
#
# Episode 7: 010_89.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 1327 pixels (2.30%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_7_010_89.gif
#
# Episode 8: 011_103.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 831 pixels (1.44%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_8_011_103.gif
#
# Episode 9: 012_69.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 1365 pixels (2.37%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_9_012_69.gif
#
# Episode 10: 013_86.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 1536 pixels (2.67%)
#   Action Distribution: [0.65 0.3  0.05]
#   GIF saved: TEST_GIFS/episode_10_013_86.gif
#
# Episode 11: 014_46.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 2035 pixels (3.53%)
#   Action Distribution: [0.  0.4 0.6]
#   GIF saved: TEST_GIFS/episode_11_014_46.gif
#
# Episode 12: 015_71.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 2195 pixels (3.81%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_12_015_71.gif
#
# Episode 13: 016_95.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -16.80, Steps to Find: 2
#   Tumor Size: 2999 pixels (5.21%)
#   Action Distribution: [0.75 0.2  0.05]
#   GIF saved: TEST_GIFS/episode_13_016_95.gif
#
# Episode 14: 017_68.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 2255 pixels (3.91%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_14_017_68.gif
#
# Episode 15: 018_84.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1676 pixels (2.91%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_15_018_84.gif
#
# Episode 16: 019_52.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1280 pixels (2.22%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_16_019_52.gif
#
# Episode 17: 021_96.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 867 pixels (1.51%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_17_021_96.gif
#
# Episode 18: 022_89.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1566 pixels (2.72%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_18_022_89.gif
#
# Episode 19: 023_98.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1119 pixels (1.94%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_19_023_98.gif
#
# Episode 20: 024_49.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 5
#   Tumor Size: 1338 pixels (2.32%)
#   Action Distribution: [0.  0.4 0.6]
#   GIF saved: TEST_GIFS/episode_20_024_49.gif
#
# Episode 21: 026_43.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 663 pixels (1.15%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_21_026_43.gif
#
# Episode 22: 028_56.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 799 pixels (1.39%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_22_028_56.gif
#
# Episode 23: 030_99.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 1979 pixels (3.44%)
#   Action Distribution: [0.8  0.15 0.05]
#   GIF saved: TEST_GIFS/episode_23_030_99.gif
#
# Episode 24: 030_115.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 611 pixels (1.06%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_24_030_115.gif
#
# Episode 25: 032_134.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 554 pixels (0.96%)
#   Action Distribution: [0.   0.45 0.55]
#   GIF saved: TEST_GIFS/episode_25_032_134.gif
#
# Episode 26: 033_86.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 2788 pixels (4.84%)
#   Action Distribution: [0.   0.65 0.35]
#   GIF saved: TEST_GIFS/episode_26_033_86.gif
#
# Episode 27: 034_113.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 2141 pixels (3.72%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_27_034_113.gif
#
# Episode 28: 035_40.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 837 pixels (1.45%)
#   Action Distribution: [0.   0.45 0.55]
#   GIF saved: TEST_GIFS/episode_28_035_40.gif
#
# Episode 29: 036_83.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 795 pixels (1.38%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_29_036_83.gif
#
# Episode 30: 038_84.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 1720 pixels (2.99%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_30_038_84.gif
#
# Episode 31: 040_46.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 3375 pixels (5.86%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_31_040_46.gif
#
# Episode 32: 043_48.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1217 pixels (2.11%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_32_043_48.gif
#
# Episode 33: 045_57.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 473 pixels (0.82%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_33_045_57.gif
#
# Episode 34: 045_82.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 2259 pixels (3.92%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_34_045_82.gif
#
# Episode 35: 046_44.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1147 pixels (1.99%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_35_046_44.gif
#
# Episode 36: 048_49.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1308 pixels (2.27%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_36_048_49.gif
#
# Episode 37: 049_81.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1649 pixels (2.86%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_37_049_81.gif
#
# Episode 38: 050_60.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 2312 pixels (4.01%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_38_050_60.gif
#
# Episode 39: 051_94.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 3155 pixels (5.48%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_39_051_94.gif
#
# Episode 40: 052_98.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 1228 pixels (2.13%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_40_052_98.gif
#
# Episode 41: 053_85.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2915 pixels (5.06%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_41_053_85.gif
#
# Episode 42: 054_61.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -16.80, Steps to Find: 2
#   Tumor Size: 2098 pixels (3.64%)
#   Action Distribution: [0.8  0.15 0.05]
#   GIF saved: TEST_GIFS/episode_42_054_61.gif
#
# Episode 43: 055_61.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -17.60, Steps to Find: 3
#   Tumor Size: 2578 pixels (4.48%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_43_055_61.gif
#
# Episode 44: 057_124.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 6
#   Tumor Size: 1433 pixels (2.49%)
#   Action Distribution: [0.  0.5 0.5]
#   GIF saved: TEST_GIFS/episode_44_057_124.gif
#
# Episode 45: 058_84.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1231 pixels (2.14%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_45_058_84.gif
#
# Episode 46: 059_67.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 730 pixels (1.27%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_46_059_67.gif
#
# Episode 47: 066_116.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 674 pixels (1.17%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_47_066_116.gif
#
# Episode 48: 090_73.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1051 pixels (1.82%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_48_090_73.gif
#
# Episode 49: 092_94.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1658 pixels (2.88%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_49_092_94.gif
#
# Episode 50: 104_74.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 100.00, Steps to Find: 1
#   Tumor Size: 3423 pixels (5.94%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_50_104_74.gif
#
# Episode 51: 116_58.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1855 pixels (3.22%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_51_116_58.gif
#
# Episode 52: 119_53.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 1148 pixels (1.99%)
#   Action Distribution: [0.6  0.35 0.05]
#   GIF saved: TEST_GIFS/episode_52_119_53.gif
#
# Episode 53: 130_39.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 742 pixels (1.29%)
#   Action Distribution: [0.  0.5 0.5]
#   GIF saved: TEST_GIFS/episode_53_130_39.gif
#
# Episode 54: 147_83.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2935 pixels (5.10%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_54_147_83.gif
#
# Episode 55: 154_87.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1443 pixels (2.51%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_55_154_87.gif
#
# Episode 56: 155_48.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 1005 pixels (1.74%)
#   Action Distribution: [0.8  0.15 0.05]
#   GIF saved: TEST_GIFS/episode_56_155_48.gif
#
# Episode 57: 160_82.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2528 pixels (4.39%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_57_160_82.gif
#
# Episode 58: 163_101.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 3132 pixels (5.44%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_58_163_101.gif
#
# Episode 59: 171_69.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1076 pixels (1.87%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_59_171_69.gif
#
# Episode 60: 176_99.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 2223 pixels (3.86%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_60_176_99.gif
#
# Episode 61: 177_57.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 823 pixels (1.43%)
#   Action Distribution: [0.55 0.4  0.05]
#   GIF saved: TEST_GIFS/episode_61_177_57.gif
#
# Episode 62: 178_85.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 84.40, Steps to Find: 4
#   Tumor Size: 2286 pixels (3.97%)
#   Action Distribution: [0.8  0.15 0.05]
#   GIF saved: TEST_GIFS/episode_62_178_85.gif
#
# Episode 63: 179_70.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1958 pixels (3.40%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_63_179_70.gif
#
# Episode 64: 180_50.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 100.00, Steps to Find: 1
#   Tumor Size: 2855 pixels (4.96%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_64_180_50.gif
#
# Episode 65: 180_72.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2771 pixels (4.81%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_65_180_72.gif
#
# Episode 66: 184_36.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 296 pixels (0.51%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_66_184_36.gif
#
# Episode 67: 188_62.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1754 pixels (3.05%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_67_188_62.gif
#
# Episode 68: 190_81.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 987 pixels (1.71%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_68_190_81.gif
#
# Episode 69: 200_45.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1239 pixels (2.15%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_69_200_45.gif
#
# Episode 70: 204_52.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 88.80, Steps to Find: 3
#   Tumor Size: 893 pixels (1.55%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_70_204_52.gif
#
# Episode 71: 226_66.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 2037 pixels (3.54%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_71_226_66.gif
#
# Episode 72: 227_60.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1494 pixels (2.59%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_72_227_60.gif
#
# Episode 73: 231_90.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 3297 pixels (5.72%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_73_231_90.gif
#
# Episode 74: 236_58.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 2498 pixels (4.34%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_74_236_58.gif
#
# Episode 75: 237_41.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -15.20, Steps to Find: 20
#   Tumor Size: 840 pixels (1.46%)
#   Action Distribution: [0.  0.3 0.7]
#   GIF saved: TEST_GIFS/episode_75_237_41.gif
#
# Episode 76: 240_52.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 2725 pixels (4.73%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_76_240_52.gif
#
# Episode 77: 245_35.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 1257 pixels (2.18%)
#   Action Distribution: [0.8  0.15 0.05]
#   GIF saved: TEST_GIFS/episode_77_245_35.gif
#
# Episode 78: 250_45.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1616 pixels (2.81%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_78_250_45.gif
#
# Episode 79: 255_56.npy
#   Success: False, Final on Tumor: False
#   Total Reward: 19.20, Steps to Find: 4
#   Tumor Size: 3030 pixels (5.26%)
#   Action Distribution: [0.   0.45 0.55]
#   GIF saved: TEST_GIFS/episode_79_255_56.gif
#
# Episode 80: 260_62.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1653 pixels (2.87%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_80_260_62.gif
#
# Episode 81: 266_105.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1725 pixels (2.99%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_81_266_105.gif
#
# Episode 82: 274_90.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 100.00, Steps to Find: 1
#   Tumor Size: 4092 pixels (7.10%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_82_274_90.gif
#
# Episode 83: 276_102.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 1831 pixels (3.18%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_83_276_102.gif
#
# Episode 84: 280_96.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 905 pixels (1.57%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_84_280_96.gif
#
# Episode 85: 282_53.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 1994 pixels (3.46%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_85_282_53.gif
#
# Episode 86: 284_88.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 4461 pixels (7.74%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_86_284_88.gif
#
# Episode 87: 287_97.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 1807 pixels (3.14%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_87_287_97.gif
#
# Episode 88: 289_74.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 3435 pixels (5.96%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_88_289_74.gif
#
# Episode 89: 299_97.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 2607 pixels (4.53%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_89_299_97.gif
#
# Episode 90: 300_107.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 2216 pixels (3.85%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_90_300_107.gif
#
# Episode 91: 308_88.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 100.00, Steps to Find: 1
#   Tumor Size: 4910 pixels (8.52%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_91_308_88.gif
#
# Episode 92: 314_91.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -16.80, Steps to Find: 20
#   Tumor Size: 932 pixels (1.62%)
#   Action Distribution: [0.7  0.25 0.05]
#   GIF saved: TEST_GIFS/episode_92_314_91.gif
#
# Episode 93: 326_68.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 89.60, Steps to Find: 3
#   Tumor Size: 1227 pixels (2.13%)
#   Action Distribution: [0.85 0.1  0.05]
#   GIF saved: TEST_GIFS/episode_93_326_68.gif
#
# Episode 94: 333_91.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 3974 pixels (6.90%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_94_333_91.gif
#
# Episode 95: 350_77.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -17.60, Steps to Find: 20
#   Tumor Size: 1879 pixels (3.26%)
#   Action Distribution: [0.85 0.05 0.1 ]
#   GIF saved: TEST_GIFS/episode_95_350_77.gif
#
# Episode 96: 356_97.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 532 pixels (0.92%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_96_356_97.gif
#
# Episode 97: 360_103.npy
#   Success: True, Final on Tumor: True
#   Total Reward: 94.80, Steps to Find: 2
#   Tumor Size: 3331 pixels (5.78%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_97_360_103.gif
#
# Episode 98: 363_48.npy
#   Success: False, Final on Tumor: False
#   Total Reward: -18.40, Steps to Find: 20
#   Tumor Size: 872 pixels (1.51%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_98_363_48.gif
#
# Episode 99: 365_83.npy
#   Success: True, Final on Tumor: True
#   Total Reward: -18.40, Steps to Find: 2
#   Tumor Size: 3872 pixels (6.72%)
#   Action Distribution: [0.9  0.05 0.05]
#   GIF saved: TEST_GIFS/episode_99_365_83.gif

# %%
# # load model to test:
# LR = 1e-4 #From paper
# CURRENT_CONFIG = {
#     'grid_size': 4,
#     'rewards': [5.0, -1.0, -0.2], 
#     'action_space': spaces.Discrete(3)
# }

# env = Glioblastoma(*test_pairs[0], **CURRENT_CONFIG)

# model = DQN(env, learning_rate=LR, device='cpu')
# #model.load_state_dict(torch.load("/home/martina/codi2/4year/tfg/grid_search/Trial124.dat"))
# model.load_state_dict(torch.load("/home/martina/codi2/4year/tfg/other_models/current/Extension020.dat"))

# agent = DQNAgent(env_config=CURRENT_CONFIG, dnnetwork=model, buffer_class=ReplayBuffer, train_pairs=test_pairs,
#                  env_class=Glioblastoma,
#                  epsilon=0.00)  # very low epsilon for testing
